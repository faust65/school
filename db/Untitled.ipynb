# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sv=pd.read_excel('섭.xlsx')
sv
# Out:
#       서버  인구(6월)  인구(7월)
# 0     노바     0.2     0.2
# 1     레드     0.9     0.8
# 2     루나    14.9    13.6
# 3    리부트    16.5    18.3
# 4   리부트2     7.2    10.6
# 5     베라     7.8     7.4
# 6   스카니아    14.1    13.3
# 7    아케인     0.3     0.3
# 8   엘리시움    14.4    13.1
# 9    오로라     6.4     6.4
# 10   유니온     1.6     1.4
# 11  이노시스     1.6     1.5
# 12   제니스     1.3     1.1
# 13   크로아    12.7    11.8

# %%
sv2=pd.read_excel('섭2.xlsx')
sv2
# Out:
#       서버    인구 6월/7월
# 0     노바   0.2    6월
# 1     레드   0.8    7월
# 2     루나  13.6    7월
# 3    리부트  16.5    6월
# 4   리부트2  10.6    7월
# 5     베라   7.8    6월
# 6   스카니아  13.3    7월
# 7    아케인   0.3    6월
# 8   엘리시움  13.1    7월
# 9    오로라   6.4    6월
# 10   유니온   1.6    6월
# 11  이노시스   1.5    7월
# 12   제니스   1.1    7월
# 13   크로아  12.7    6월
# 14   크로아  11.8    7월
# 15    노바   0.2    7월
# 16    레드   0.9    6월
# 17    루나  14.9    6월
# 18   리부트  18.3    7월
# 19  리부트2   7.2    6월
# 20    베라   7.4    7월
# 21  스카니아  14.1    6월
# 22   아케인   0.3    7월
# 23  엘리시움  14.4    6월
# 24   오로라   6.4    7월
# 25   유니온   1.4    7월
# 26  이노시스   1.6    6월
# 27   제니스   1.3    6월

# %%
job=pd.read_excel('직.xlsx')
job
# Out:
#             직업    인구
# 0        나이트로드  4.32
# 1       듀얼블레이더  4.81
# 2          바이퍼  4.42
# 3           비숍  3.47
# 4          섀도어  3.78
# 5        소울마스터  5.52
# 6           아델  8.73
# 7   아크메이지(썬,콜)  3.58
# 8           은월  2.51
# 9       윈드브레이커  3.88
# 10          칼리  3.93
# 11         팔라딘  2.72
# 12       패스파인더  3.27
# 13          호영  2.77
# 14         히어로  3.80

# %%
cng=pd.read_excel('변.xlsx')
cng
# Out:
#   2023년    루나  스카니아   리부트  엘리시움
# 0    4월  16.1  15.6  12.8  12.6
# 1    5월  15.9  15.4  13.6  12.4
# 2    6월  14.9  14.1  16.5  14.4
# 3    7월  13.6  13.3  18.3  13.1

# %%
plt.rcParams['font.family']='malgun gothic'
plt.rcParams['font.size']=8
sns.barplot(data=job, x='인구',y='직업')
plt.xlabel('인구(%)')
# Out:
# Text(0.5, 0, '인구(%)')

# %%
sns.lineplot(data=cng,x='2023년',y='루나', label='루나')
sns.lineplot(data=cng,x='2023년',y='스카니아', label='스카니아')
sns.lineplot(data=cng,x='2023년',y='리부트', label='리부트')
sns.lineplot(data=cng,x='2023년',y='엘리시움', label='엘리시움')
plt.ylabel('인구(%)')
# Out:
# Text(0, 0.5, '인구(%)')

# %%
sns.barplot(data=sv2, x='인구',y='서버',hue='6월/7월')
plt.xlabel('인구(%)')
# Out:
# Text(0.5, 0, '인구(%)')

# %%
plt.pie(data=sv,x="인구(7월)",labels="서버", colors=colors,autopct='%.0f%%')
colors=sns.color_palette('pastel')
